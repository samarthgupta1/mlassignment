# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# QUESTION 1
import os 
path=os.getcwd()+"\desktop\house_price.csv"
df=pd.read_csv(path)
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
df.describe()
# it is dataset of house pricing means how much house cost .It has columns like house id ,price related to that id ,house discription eg: no of bedroom,which fllor it is etc.It also tell teh location of house like lattitude,longitude etc.
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
# QUESTION 2
df.isnull().sum()
#Actually there are no missing value no missing value but if it have than if there very less missing values like 1 to 5 than i have drop it ,otherwise i have fill it.
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
# QUESTION 3
sns.distplot(df["price"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
df.price.hist(figsize=(10,8))

# %%
df.fillna(df.median())
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000   221900.0         3       1.00
# 1      6414100192  20141209T000000   538000.0         3       2.25
# 2      5631500400  20150225T000000   180000.0         2       1.00
# 3      2487200875  20141209T000000   604000.0         4       3.00
# 4      1954400510  20150218T000000   510000.0         3       2.00
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 6      1321400060  20140627T000000   257500.0         3       2.25
# 7      2008000270  20150115T000000   291850.0         3       1.50
# 8      2414600126  20150415T000000   229500.0         3       1.00
# 9      3793500160  20150312T000000   323000.0         3       2.50
# 10     1736800520  20150403T000000   662500.0         3       2.50
# 11     9212900260  20140527T000000   468000.0         2       1.00
# 12      114101516  20140528T000000   310000.0         3       1.00
# ...

# %%
sns.boxplot(data=df['price'])

# %%
sns.boxplot(data=df["bedrooms"])

# %%
sns.boxplot(data=df["bathrooms"])

# %%
plt.figure(figsize=(10,8))
sns.boxplot(data=df["sqft_living"])

# %%
plt.figure(figsize=(10,8))
sns.countplot(x="bedrooms",data=df)

# %%
# QUESTION 4
plt.scatter(x=df.sqft_lot,y=df.sqft_lot15)

# %%
df=df[df["sqft_lot"]<= 1250000]
df=df[df["sqft_lot15"]<800000]

# %%
plt.scatter(x=df.sqft_lot,y=df.sqft_lot15)

# %%
plt.figure(figsize=(20,15))
sns.jointplot(x="price",y="bedrooms",data=df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
df=df[df["bedrooms"]<30]

# %%
plt.figure(figsize=(20,15))
sns.jointplot(x="price",y="bedrooms",data=df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x="bedrooms",y="bathrooms",data=df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plt.figure(figsize=(10,10))
sns.lmplot(x="sqft_living",y="sqft_living15",data=df,hue="bedrooms",fit_reg=False)

# %%
sns.lmplot(x="sqft_lot",y="sqft_lot15",data=df,hue="floors",fit_reg=False)

# %%
df=df[df["sqft_lot15"]<=500000]
df=df[df["sqft_lot"]<1000000]

# %%
sns.lmplot(x="sqft_lot",y="sqft_lot15",data=df,hue="floors",fit_reg=False)

# %%
sns.barplot(x="floors",y="price",data=df)

# %%
sns.boxplot(x="floors",y="price",data=df)

# %%
plt.figure(figsize=(20,15))
sns.countplot(hue="floors",x="price",data=df)

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr())

# %%
# i have find that the highest price of house is for that has general 5 to 6 bedrooms , also that 5 to 6 bedrooms house have most bathrooms,also that 5 bedrooms house most sqft living

# %%
# QUESTION 5
n=list(set(["price","bedrooms","bathrooms","floors"]))
corr=df[n].corr()
sns.heatmap(corr)

# %%
sns.pairplot(df[n])

# %%
plt.figure(figsize=(12,10))
sns.countplot(x="bedrooms",hue="floors",data=df)

# %%
# with this I get know that most 3bedrooms house areon 1st floor,also get that there is relation between floor and price

# %%
# QUESTION 6

# According to me the most 3 interesting graph are "HEATMAP","LMPLOT","SCATTER",because for me these 3 graph have hepled me most to finf relation and remove outliers
