# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
import os 
path=os.getcwd()+"\desktop\sample.csv"
df=pd.read_csv(path)
df.head()
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# 1         ENE           39.0          E      ...               36
# 2          NW           85.0          N      ...               69
# 3          NW           54.0        WNW      ...               56
# 4         SSE           50.0        SSE      ...               49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
# 1
plt.scatter(df["MinTemp"],df["MaxTemp"])

# %%
# 2
plt.scatter(df["Cloud9am"],df["Cloud3pm"])

# %%
# 3
plt.scatter(df["Pressure9am"],df["Pressure3pm"])

# %%
# 4
plt.figure(1)
plt.subplot(211)
plt.scatter(df["Pressure9am"],df["Pressure3pm"])
plt.legend()
plt.subplot(212)
plt.scatter(df["MinTemp"],df["MaxTemp"])
plt.legend()

# %%
# 5
plt.hist(df["Evaporation"])
# Out:
# (array([ 37., 102.,  51.,  55.,  55.,  28.,  25.,   8.,   3.,   2.]),
#  array([ 0.2 ,  1.56,  2.92,  4.28,  5.64,  7.  ,  8.36,  9.72, 11.08,
#         12.44, 13.8 ]),
#  <a list of 10 Patch objects>)

# %%
# 6
sns.distplot(df["MinTemp"],kde=True,hist=True,rug=True,color="b")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
# 7
sns.kdeplot(df["Sunshine"],color="b",shade=True,bw=4)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:448: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:448: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.

# %%
# 8
plt.figure(1)
plt.subplot(121)
plt.hist(df["Evaporation"])
plt.legend()
plt.subplot(122)
sns.distplot(df["MinTemp"],kde=True,hist=True,rug=True,color="b")
plt.legend()
# Out:
# No handles with labels found to put in legend.
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# No handles with labels found to put in legend.

# %%
# 9
plt.figure(figsize=(8,8))
sns.kdeplot(df["MinTemp"],df["MaxTemp"],shade=True)

# %%
# 10
plt.figure(figsize=(8,8))
sns.jointplot(df["Pressure9am"],df["Pressure3pm"],kind="kde",color="r",shade=False)

# %%
# 11
sns.lmplot(x="MinTemp",y="MaxTemp",data=df,hue="WindGustDir",fit_reg=True)

# %%
# 12
sns.lmplot(x="Pressure9am",y="Pressure3pm",data=df,hue="WindGustDir",fit_reg=False)

# %%
# 13
plt.figure(figsize=(30,20))
sns.stripplot(x="WindGustDir",y="MinTemp",data=df)

# %%
# 14
plt.figure(figsize=(30,20))
sns.swarmplot(x="Cloud9am",y="MinTemp",data=df)

# %%
# 15
plt.figure(figsize=(30,20))
sns.swarmplot(x="WindGustDir",y="MinTemp",data=df)

# %%
# 16
plt.figure(figsize=(15,10))
sns.boxplot(x="WindGustDir",y="Rainfall",data=df)

# %%
# 17
plt.figure(figsize=(15,10))
sns.barplot(x="WindGustDir",y="Evaporation",data=df)

# %%
# 18
plt.figure(figsize=(15,10))
sns.countplot(x="WindGustDir",data=df)

# %%
# 19
plt.figure(figsize=(15,10))
sns.countplot(x="Cloud9am",data=df)

# %%
# 20
plt.figure(figsize=(15,10))
corr=df.corr()
sns.heatmap(corr)
